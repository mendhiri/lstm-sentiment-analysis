# %%
import pandas as pd

df = pd.read_csv('./scraped_tniad_tweets.csv')
df.nunique()
# Out:
# username      98
# date        1639
# tweet       1796
# fullname      98
# dtype: int64

# %%
df.shape
# Out:
# (1860, 4)
